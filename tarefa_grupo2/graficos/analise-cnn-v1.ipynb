# %% [markdown]
# # **Codigo 01Utilizado para baixar o dataset de raios-x do peito relacionado ao COVID-19#Direto do KaggleHub**

# %%
import kagglehub
import pandas as pd
import os
import shutil

# --- Configurações de Caminho ---
# Define o diretório de destino onde o dataset do Kaggle será salvo no Colab.
# Será criado em /content/coronahack_dataset/
DESTINATION_FOLDER = "/content/coronahack_dataset"

# Define o nome do dataset no Kaggle Hub
KAGGLE_DATASET_NAME = "praveengovi/coronahack-chest-xraydataset"

# --- 1. Garante que o diretório de destino exista e esteja limpo (opcional) ---
# Se você quer ter certeza de que a pasta está sempre limpa antes de copiar,
# descomente as duas linhas abaixo.
# print(f"Verificando e limpando o diretório de destino: {DESTINATION_FOLDER}")
# if os.path.exists(DESTINATION_FOLDER):
#     shutil.rmtree(DESTINATION_FOLDER)
os.makedirs(DESTINATION_FOLDER, exist_ok=True)
print(f"Diretório de destino garantido: {DESTINATION_FOLDER}")

# --- 2. Baixa o dataset do Kaggle Hub ---
print(f"\nBaixando o dataset '{KAGGLE_DATASET_NAME}' do Kaggle...")
downloaded_path = kagglehub.dataset_download(KAGGLE_DATASET_NAME)
print(f"Dataset baixado para o cache: {downloaded_path}")

# --- 3. Identifica e Copia os arquivos para o diretório de destino final ---
# A estrutura do dataset baixado é geralmente: downloaded_path/Chest_xray_Corona_Metadata.csv
# e downloaded_path/Coronahack-Chest-XRay-Dataset/
SOURCE_METADATA_FILE = os.path.join(downloaded_path, "Chest_xray_Corona_Metadata.csv")
SOURCE_IMAGES_FOLDER = os.path.join(downloaded_path, "Coronahack-Chest-XRay-Dataset")

# Copia o arquivo CSV de metadados
try:
    shutil.copy(SOURCE_METADATA_FILE, os.path.join(DESTINATION_FOLDER, "Chest_xray_Corona_Metadata.csv"))
    print(f"CSV de metadados copiado para: {os.path.join(DESTINATION_FOLDER, 'Chest_xray_Corona_Metadata.csv')}")
except Exception as e:
    print(f"ERRO ao copiar o arquivo CSV: {e}")

# Copia a pasta de imagens
# Precisa garantir que a pasta de destino para as imagens não exista antes de usar copytree
DESTINATION_IMAGES_FOLDER = os.path.join(DESTINATION_FOLDER, "Coronahack-Chest-XRay-Dataset")
if os.path.exists(DESTINATION_IMAGES_FOLDER):
    print(f"Removendo pasta de imagens existente em {DESTINATION_IMAGES_FOLDER}...")
    shutil.rmtree(DESTINATION_IMAGES_FOLDER)
try:
    shutil.copytree(SOURCE_IMAGES_FOLDER, DESTINATION_IMAGES_FOLDER)
    print(f"Pasta de imagens copiada para: {DESTINATION_IMAGES_FOLDER}")
except Exception as e:
    print(f"ERRO ao copiar a pasta de imagens: {e}")

# --- 4. Carrega o DataFrame principal e verifica a estrutura final ---
# O DataFrame será carregado da localização final dentro do Colab
df_x_ray = pd.read_csv(os.path.join(DESTINATION_FOLDER, "Chest_xray_Corona_Metadata.csv"))

print(f"\nVerificando a estrutura final em {DESTINATION_FOLDER}:")
# !ls -d */ {DESTINATION_FOLDER}

print("\n--- Download e Organização do Dataset Concluídos ---")
print("Primeiras linhas do DataFrame 'df_x_ray':")
print(df_x_ray.head())
print(f"O caminho base para suas imagens originais é: {DESTINATION_FOLDER}")
# Out:
# Diretório de destino garantido: /content/coronahack_dataset
#
# Baixando o dataset 'praveengovi/coronahack-chest-xraydataset' do Kaggle...
# Dataset baixado para o cache: /kaggle/input/coronahack-chest-xraydataset
# CSV de metadados copiado para: /content/coronahack_dataset/Chest_xray_Corona_Metadata.csv
# Pasta de imagens copiada para: /content/coronahack_dataset/Coronahack-Chest-XRay-Dataset
#
# Verificando a estrutura final em /content/coronahack_dataset:
# ls: cannot access '*/': No such file or directory
#  /content/coronahack_dataset
#
# --- Download e Organização do Dataset Concluídos ---
# Primeiras linhas do DataFrame 'df_x_ray':
#    Unnamed: 0   X_ray_image_name   Label Dataset_type Label_2_Virus_category  \
# 0           0  IM-0128-0001.jpeg  Normal        TRAIN                    NaN
# 1           1  IM-0127-0001.jpeg  Normal        TRAIN                    NaN
# 2           2  IM-0125-0001.jpeg  Normal        TRAIN                    NaN
# 3           3  IM-0122-0001.jpeg  Normal        TRAIN                    NaN
# 4           4  IM-0119-0001.jpeg  Normal        TRAIN                    NaN
#
#   Label_1_Virus_category
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# O caminho base para suas imagens originais é: /content/coronahack_dataset

# %% [markdown]
# # Código 2:Verificar o Balanceamento das Classes e gerar grafico

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# Caminho para o CSV de metadados
BASE_FOLDER = '/content/coronahack_dataset'
ORIGINAL_METADATA_CSV = os.path.join(BASE_FOLDER, 'Chest_xray_Corona_Metadata.csv')

# Carrega o CSV
df = pd.read_csv(ORIGINAL_METADATA_CSV)

# Corrige erro de grafia
df['Label'] = df['Label'].replace('Pnemonia', 'Pneumonia')

# Define classes finais
df['final_label'] = 'Outros'
df.loc[df['Label'] == 'Normal', 'final_label'] = 'Normal'
df.loc[(df['Label'] == 'Pneumonia') & (df['Label_1_Virus_category'] == 'Virus'), 'final_label'] = 'Pneumonia Viral'
df.loc[(df['Label'] == 'Pneumonia') & (df['Label_1_Virus_category'] == 'bacteria'), 'final_label'] = 'Pneumonia Bacteriana'

# Remove classe "Outros"
df_classified = df[df['final_label'] != 'Outros']

# Conta imagens por classe e por tipo de dataset (TRAIN/TEST)
class_counts = df_classified.groupby(['Dataset_type', 'final_label']).size().reset_index(name='count')

# --- Visualização com Seaborn ---
plt.figure(figsize=(10, 6))
sns.barplot(data=class_counts, x='final_label', y='count', hue='Dataset_type')
plt.title('Distribuição das Classes por Tipo de Conjunto (TRAIN / TEST)')
plt.ylabel('Número de Imagens')
plt.xlabel('Classe')
plt.tight_layout()
plt.show()

# --- Imprime os números brutos também ---
print("\nContagem por Classe e Tipo de Conjunto:")
print(class_counts.pivot(index='final_label', columns='Dataset_type', values='count').fillna(0).astype(int))
# Out:
# Contagem por Classe e Tipo de Conjunto:
# Dataset_type          TEST  TRAIN
# final_label
# Normal                 234   1342
# Pneumonia Bacteriana   242   2535
# Pneumonia Viral        148   1407

# %% [markdown]
# # Codigo 2
# # Limpeza do data set e organização das colunas
# # Reorganização dos arquivos das imagens para obtermos um conjunto de dados balanceados corrigindo distorções
# # trainamento 80% teste 10% validação 10%

# %%
import pandas as pd
import os
import shutil
from PIL import Image
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import logging

# --- Configuração Inicial ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# --- DEFINIÇÃO DOS CAMINHOS ---
BASE_FOLDER = '/content/coronahack_dataset'
ORIGINAL_METADATA_CSV = os.path.join(BASE_FOLDER, 'Chest_xray_Corona_Metadata.csv')

# Caminho corrigido para a pasta de imagens (ajuste se a estrutura for diferente no seu ambiente)
ORIGINAL_IMAGES_FOLDER = os.path.join(BASE_FOLDER, 'Coronahack-Chest-XRay-Dataset', 'Coronahack-Chest-XRay-Dataset')

PROCESSED_DATA_FOLDER = '/content/dados_processados'
TARGET_IMAGE_SIZE = (128, 128)
VALIDATION_SET_SIZE = 0.20 # Define o tamanho do conjunto de validação em relação ao TRAIN original
RANDOM_STATE = 42 # Para reprodutibilidade

# --- FUNÇÃO PARA PROCESSAR E ORGANIZAR AS IMAGENS ---
def process_and_organize_images(dataframe: pd.DataFrame, set_name: str):
    logging.info(f"Processando e organizando {len(dataframe)} imagens para o conjunto '{set_name}'...")

    # Limpar a pasta de destino para evitar mistura de execuções anteriores, se existir
    set_destination_folder = os.path.join(PROCESSED_DATA_FOLDER, set_name)
    if os.path.exists(set_destination_folder):
        logging.info(f"Removendo pasta existente: {set_destination_folder}")
        shutil.rmtree(set_destination_folder)
    os.makedirs(set_destination_folder, exist_ok=True) # Criar novamente

    for _, row in tqdm(dataframe.iterrows(), total=len(dataframe), desc=f"Processando conjunto {set_name}"):
        try:
            image_name = row['X_ray_image_name']
            image_label = row['final_label']
            dataset_type_folder = row['Dataset_type'].lower() # 'train' ou 'test'

            # Construir o caminho da imagem original
            source_path = os.path.join(ORIGINAL_IMAGES_FOLDER, dataset_type_folder, image_name)

            # Define pasta e nome de destino
            destination_folder_path = os.path.join(PROCESSED_DATA_FOLDER, set_name, image_label)
            os.makedirs(destination_folder_path, exist_ok=True) # Cria a subpasta da classe
            new_image_name = os.path.splitext(image_name)[0] + ".jpeg"
            destination_file_path = os.path.join(destination_folder_path, new_image_name)

            with Image.open(source_path) as img:
                if img.mode != 'RGB':
                    img = img.convert('RGB')
                img_resized = img.resize(TARGET_IMAGE_SIZE, Image.LANCZOS)
                img_resized.save(destination_file_path, format='jpeg', quality=95)

        except FileNotFoundError:
            logging.warning(f"Arquivo não encontrado e ignorado: {source_path}")
        except Exception as e:
            logging.error(f"Erro ao processar o arquivo {source_path}: {e}")

# --- BLOCO DE EXECUÇÃO PRINCIPAL ---
if __name__ == '__main__':
    logging.info("--- INICIANDO FASE 1: PREPARAÇÃO E ORGANIZAÇÃO DOS DADOS ---")

    # 0. Limpar pasta de saída principal para uma execução limpa
    if os.path.exists(PROCESSED_DATA_FOLDER):
        logging.info(f"Removendo pasta de dados processados existente: {PROCESSED_DATA_FOLDER}")
        shutil.rmtree(PROCESSED_DATA_FOLDER)
    os.makedirs(PROCESSED_DATA_FOLDER, exist_ok=True) # Criar novamente

    if not os.path.exists(ORIGINAL_METADATA_CSV):
        logging.error(f"ERRO: Arquivo '{ORIGINAL_METADATA_CSV}' não encontrado. Execute o Código 1 (ou baixe o dataset) primeiro.")
    else:
        # 1. Ler o CSV.
        original_df = pd.read_csv(ORIGINAL_METADATA_CSV)

        # Verifica colunas obrigatórias
        required_cols = ['Label', 'Label_1_Virus_category', 'Dataset_type', 'X_ray_image_name']
        if not all(col in original_df.columns for col in required_cols):
            raise ValueError(f"CSV está faltando colunas esperadas: {required_cols}")

        # Corrige erros de grafia
        original_df['Label'] = original_df['Label'].replace('Pnemonia', 'Pneumonia')

        # 2. Filtrar as 3 classes-alvo e criar 'final_label'
        logging.info("Definindo 3 classes alvo e limpando metadados...")
        original_df['final_label'] = 'Outros'
        original_df.loc[original_df['Label'] == 'Normal', 'final_label'] = 'Normal'
        original_df.loc[(original_df['Label'] == 'Pneumonia') & (original_df['Label_1_Virus_category'] == 'Virus'), 'final_label'] = 'Pneumonia Viral'
        original_df.loc[(original_df['Label'] == 'Pneumonia') & (original_df['Label_1_Virus_category'] == 'bacteria'), 'final_label'] = 'Pneumonia Bacteriana'

        df_classified = original_df[original_df['final_label'] != 'Outros'].copy()

        # 3. Separar o conjunto TEST como está.
        logging.info("Separando conjunto de Teste...")
        df_test = df_classified[df_classified['Dataset_type'].str.upper() == 'TEST'].copy()
        logging.info(f"Tamanho do conjunto de Teste: {len(df_test)}")
        logging.info(f"Distribuição do Teste:\n{df_test['final_label'].value_counts()}")

        # Obter o conjunto TRAIN original completo
        df_train_original_full = df_classified[df_classified['Dataset_type'].str.upper() == 'TRAIN'].copy()
        logging.info(f"Tamanho do conjunto TRAIN original completo: {len(df_train_original_full)}")
        logging.info(f"Distribuição original do TRAIN:\n{df_train_original_full['final_label'].value_counts()}")

        # --- NOVA LÓGICA DE DIVISÃO E BALANCEAMENTO ---
        logging.info("Dividindo o conjunto TRAIN original em Treino e Validação (estratificado para Validação)...")

        # 4a. Separar o conjunto de Validação de forma ESTRATIFICADA do df_train_original_full
        # Isso garante que a validação tenha uma distribuição de classes similar à do TRAIN original.
        df_temp_train, df_validation = train_test_split(
            df_train_original_full,
            test_size=VALIDATION_SET_SIZE,
            random_state=RANDOM_STATE,
            stratify=df_train_original_full['final_label'] # Isso é chave para balancear a validação
        )
        logging.info(f"Tamanho do conjunto de Validação (estratificado): {len(df_validation)}")
        logging.info(f"Distribuição do Validação (estratificado):\n{df_validation['final_label'].value_counts()}")

        # 4b. Balancear o conjunto de Treino (df_temp_train) usando under-sampling
        logging.info("Balanceando o conjunto de Treino restante (via under-sampling)...")
        class_counts_temp_train = df_temp_train['final_label'].value_counts()
        min_class_count_temp_train = class_counts_temp_train.min()
        logging.info(f"Tamanho da classe minoritária no TRAIN temporário para balanceamento: {min_class_count_temp_train}")

        df_train_balanced_list = []
        for label in df_temp_train['final_label'].unique():
            class_df = df_temp_train[df_temp_train['final_label'] == label].copy()
            # Fazer under-sampling para o tamanho da menor classe
            df_train_balanced_list.append(class_df.sample(n=min_class_count_temp_train, random_state=RANDOM_STATE))

        df_train = pd.concat(df_train_balanced_list).sample(frac=1, random_state=RANDOM_STATE).reset_index(drop=True)

        logging.info(f"Tamanhos dos conjuntos finais: {len(df_train)} (Treino Balanceado), {len(df_validation)} (Validação Estratificada), {len(df_test)} (Teste).")
        logging.info(f"Distribuição final do Treino Balanceado:\n{df_train['final_label'].value_counts()}")
        logging.info(f"Distribuição final da Validação Estratificada:\n{df_validation['final_label'].value_counts()}")

        # 5. Redimensionar e organizar as pastas
        process_and_organize_images(df_train, 'train') # As imagens do treino balanceado
        process_and_organize_images(df_validation, 'validation') # As imagens da validação estratificada
        process_and_organize_images(df_test, 'test') # As imagens do teste original

        # Salva os metadados dos novos conjuntos
        df_train.to_csv(os.path.join(PROCESSED_DATA_FOLDER, 'train_metadata.csv'), index=False)
        df_validation.to_csv(os.path.join(PROCESSED_DATA_FOLDER, 'validation_metadata.csv'), index=False)
        df_test.to_csv(os.path.join(PROCESSED_DATA_FOLDER, 'test_metadata.csv'), index=False)

        logging.info("\n--- FASE 1 CONCLUÍDA COM SUCESSO ---")
        logging.info(f"Dados processados e salvos em: '{PROCESSED_DATA_FOLDER}'")

        print("\nVerificando a estrutura de pastas final (amostra):")
        os.system(f'ls -R {PROCESSED_DATA_FOLDER} | head -n 15')
        print(f"\nDetalhes de contagem das classes no conjunto 'train':\n{df_train['final_label'].value_counts()}")
        print(f"\nDetalhes de contagem das classes no conjunto 'validation':\n{df_validation['final_label'].value_counts()}")
        print(f"\nDetalhes de contagem das classes no conjunto 'test':\n{df_test['final_label'].value_counts()}")
# Out:
# Processando conjunto train: 100%|██████████| 3222/3222 [01:19<00:00, 40.52it/s]
# Processando conjunto validation: 100%|██████████| 1057/1057 [00:24<00:00, 43.81it/s]
# Processando conjunto test: 100%|██████████| 624/624 [00:14<00:00, 42.57it/s]
# Verificando a estrutura de pastas final (amostra):
# /content/dados_processados:
# test
# test_metadata.csv
# train
# train_metadata.csv
# validation
# validation_metadata.csv
#
# /content/dados_processados/test:
# Normal
# Pneumonia Bacteriana
# Pneumonia Viral
#
# /content/dados_processados/test/Normal:
# IM-0001-0001.jpeg
#
# Detalhes de contagem das classes no conjunto 'train':
# final_label
# Pneumonia Viral         1074
# Pneumonia Bacteriana    1074
# Normal                  1074
# Name: count, dtype: int64
#
# Detalhes de contagem das classes no conjunto 'validation':
# final_label
# Pneumonia Bacteriana    507
# Pneumonia Viral         282
# Normal                  268
# Name: count, dtype: int64
#
# Detalhes de contagem das classes no conjunto 'test':
# final_label
# Pneumonia Bacteriana    242
# Normal                  234
# Pneumonia Viral         148
# Name: count, dtype: int64
# ls: write error: Broken pipe

# %% [markdown]
# # GRAFICO DOS DATAFRAME BALACEADOS

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# --- DEFINIÇÃO DOS CAMINHOS PARA OS DADOS PROCESSADOS ---
PROCESSED_DATA_FOLDER = '/content/dados_processados'
TRAIN_METADATA_CSV = os.path.join(PROCESSED_DATA_FOLDER, 'train_metadata.csv')
VALIDATION_METADATA_CSV = os.path.join(PROCESSED_DATA_FOLDER, 'validation_metadata.csv')
TEST_METADATA_CSV = os.path.join(PROCESSED_DATA_FOLDER, 'test_metadata.csv')

# Verifica se os arquivos de metadados processados existem
if not all(os.path.exists(f) for f in [TRAIN_METADATA_CSV, VALIDATION_METADATA_CSV, TEST_METADATA_CSV]):
    print("Erro: Os arquivos de metadados processados não foram encontrados.")
    print("Por favor, execute o código que gera os conjuntos de Treino, Validação e Teste (com o balanceamento) primeiro.")
    print(f"Esperava encontrar os arquivos em: {PROCESSED_DATA_FOLDER}")
else:
    # Carrega os CSVs processados
    df_train = pd.read_csv(TRAIN_METADATA_CSV)
    df_validation = pd.read_csv(VALIDATION_METADATA_CSV)
    df_test = pd.read_csv(TEST_METADATA_CSV)

    # Adiciona uma coluna 'Set_Type' para identificar cada conjunto
    df_train['Set_Type'] = 'TREINO'
    df_validation['Set_Type'] = 'VALIDAÇÃO'
    df_test['Set_Type'] = 'TESTE'

    # Concatena todos os DataFrames em um único para visualização
    df_combined = pd.concat([df_train, df_validation, df_test])

    # Conta imagens por classe e por tipo de conjunto (TREINO/VALIDAÇÃO/TESTE)
    class_counts = df_combined.groupby(['Set_Type', 'final_label']).size().reset_index(name='count')

    # --- Visualização com Seaborn ---
    plt.figure(figsize=(12, 7)) # Aumenta o tamanho para melhor visualização com 3 conjuntos
    sns.barplot(data=class_counts, x='final_label', y='count', hue='Set_Type', palette='viridis')
    plt.title('Distribuição das Classes nos Conjuntos Processados')
    plt.ylabel('Número de Imagens')
    plt.xlabel('Classe')
    plt.xticks(rotation=15) # Rotaciona os rótulos do eixo X para melhor leitura
    plt.tight_layout()
    plt.show()

    # --- Imprime os números brutos também ---
    print("\nContagem por Classe e Tipo de Conjunto (Dados Processados):")
    print(class_counts.pivot(index='final_label', columns='Set_Type', values='count').fillna(0).astype(int))
# Out:
# Contagem por Classe e Tipo de Conjunto (Dados Processados):
# Set_Type              TESTE  TREINO  VALIDAÇÃO
# final_label
# Normal                  234    1074        268
# Pneumonia Bacteriana    242    1074        507
# Pneumonia Viral         148    1074        282

# %% [markdown]
# # INICIO DA FASE 2
# # Construção e Treinamento do Modelo de Deep Learning
# # CODIGO 3
# # Usar o TensorFlow/Keras para a normalização de pixel

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Configuração do Data Augmentation para o conjunto de TREINO
train_datagen = ImageDataGenerator(
    rescale=1./255, # Normalização para [0,1] - essencial!
    rotation_range=15, # Exemplo: rotação aleatória de até 15 graus
    zoom_range=0.1,    # Exemplo: zoom aleatório de até 10%
    width_shift_range=0.1, # Exemplo: deslocamento horizontal de até 10%
    height_shift_range=0.1, # Exemplo: deslocamento vertical de até 10%
    horizontal_flip=True,  # Exemplo: espelhamento horizontal
    # vertical_flip=True, # Depende do tipo de imagem (para raios-X, geralmente não faz sentido)
    fill_mode='nearest'    # Preenche pixels novos após transformações
)

# Configuração para VALIDAÇÃO e TESTE (apenas normalização, sem aumento de dados)
# Não se aplica Data Augmentation nos conjuntos de validação e teste para que
# a avaliação seja feita em dados realistas e sem distorções artificiais.
validation_test_datagen = ImageDataGenerator(rescale=1./255)

# Em seguida, você criaria os geradores de dados para cada conjunto:
train_generator = train_datagen.flow_from_directory(
    '/content/dados_processados/train',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical' # Supondo 3 classes de saída ('Normal', 'Pneumonia Viral', 'Pneumonia Bacteriana')
)

validation_generator = validation_test_datagen.flow_from_directory(
    '/content/dados_processados/validation',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical'
)

test_generator = validation_test_datagen.flow_from_directory(
    '/content/dados_processados/test',
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    shuffle=False # Importante para garantir a ordem para avaliação final
)
# Out:
# 2025-06-13 17:38:03.746584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749836283.939714      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749836283.996151      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 3222 images belonging to 3 classes.
# Found 1057 images belonging to 3 classes.
# Found 624 images belonging to 3 classes.

# %% [markdown]
# # CODIGO 4
# # Construção e Treinamento do Modelo de Deep Learning

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # Suprime mensagens INFO e WARNING

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG16, ResNet50, MobileNetV2 # Escolha um!
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau # Adicionado ReduceLROnPlateau
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # Importa plot aqui para melhor organização

# --- 1. DEFINIÇÃO DOS CAMINHOS E PARÂMETROS ---
PROCESSED_DATA_FOLDER = '/content/dados_processados'
TRAIN_DIR = os.path.join(PROCESSED_DATA_FOLDER, 'train')
VALIDATION_DIR = os.path.join(PROCESSED_DATA_FOLDER, 'validation')
TEST_DIR = os.path.join(PROCESSED_DATA_FOLDER, 'test')

TARGET_IMAGE_SIZE = (128, 128) # Tamanho das imagens processadas
BATCH_SIZE = 32
NUM_EPOCHS_PHASE1 = 20 # Número de épocas para a primeira fase (cabeça congelada)
NUM_EPOCHS_PHASE2 = 30 # Número de épocas para a segunda fase (fine-tuning)
TOTAL_EPOCHS = NUM_EPOCHS_PHASE1 + NUM_EPOCHS_PHASE2 # Total de épocas para os gráficos

LEARNING_RATE = 0.001 # Taxa de aprendizado inicial
FINE_TUNE_LEARNING_RATE = LEARNING_RATE / 10 # Taxa de aprendizado para fine-tuning (geralmente menor)

RANDOM_STATE = 42

# Para obter o número de classes dinamicamente
try:
    df_train_meta = pd.read_csv(os.path.join(PROCESSED_DATA_FOLDER, 'train_metadata.csv'))
    NUM_CLASSES = len(df_train_meta['final_label'].unique())
    print(f"Número de classes detectado: {NUM_CLASSES}")
except FileNotFoundError:
    print("Erro: train_metadata.csv não encontrado. Defina NUM_CLASSES manualmente ou execute a Fase 1 novamente.")
    NUM_CLASSES = 3 # Valor padrão se o arquivo não for encontrado


# --- 2. PREPARAR OS DATA GENERATORS (Com Normalização e Data Augmentation) ---
print("Configurando Data Generators...")

train_datagen = ImageDataGenerator(
    rescale=1./255, # Normalização [0,1]
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

validation_test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=TARGET_IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=RANDOM_STATE
)

validation_generator = validation_test_datagen.flow_from_directory(
    VALIDATION_DIR,
    target_size=TARGET_IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=RANDOM_STATE
)

test_generator = validation_test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=TARGET_IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=RANDOM_STATE
)

# --- 3. CONSTRUIR O MODELO (Transfer Learning - FASE 1: Congelado) ---
print("\nConstruindo o modelo com Transfer Learning (Fase 1: Base Congelada)...")

base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(TARGET_IMAGE_SIZE[0], TARGET_IMAGE_SIZE[1], 3))

# Congelar as camadas do modelo base para que não sejam treinadas na Fase 1
for layer in base_model.layers:
    layer.trainable = False

# Adicionar novas camadas no topo do modelo base
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# --- 4. COMPILAR O MODELO (Fase 1) ---
print("\nCompilando o modelo para a Fase 1...")
model.compile(
    optimizer=Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

model.summary()

# --- 5. CONFIGURAR CALLBACKS (Early Stopping e Model Checkpoint) ---
# Early Stopping: para parar o treinamento se a validação parar de melhorar
# Paciência aumentada para 20 épocas
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20, # Aumentado para 20
    restore_best_weights=True
)

# Model Checkpoint: para salvar os melhores pesos do modelo durante o treinamento
# Salvará o melhor modelo geral (depois das duas fases)
checkpoint_filepath = os.path.join(PROCESSED_DATA_FOLDER, 'best_model.keras')
model_checkpoint = ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# Adicionado Learning Rate Scheduler
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2, # Reduz a LR em 80% (multiplica por 0.2)
    patience=5, # Espera 5 épocas sem melhora na val_loss antes de reduzir
    min_lr=0.000001, # LR mínima
    verbose=1
)


# --- 6. TREINAR O MODELO (FASE 1: Camadas congeladas) ---
print("\nIniciando o treinamento do modelo (Fase 1: Cabeça de Classificação)...")
history1 = model.fit(
    train_generator,
    # steps_per_epoch=train_generator.samples // BATCH_SIZE, # REMOVA ESTA LINHA
    epochs=NUM_EPOCHS_PHASE1,
    validation_data=validation_generator,
    # validation_steps=validation_generator.samples // BATCH_SIZE, # REMOVA ESTA LINHA
    callbacks=[early_stopping, model_checkpoint, reduce_lr]
)


# --- 7. FINE-TUNING (FASE 2: Descongelar e Treinar Últimas Camadas) ---
print("\nIniciando o Fine-tuning (Fase 2: Descongelando e Treinando parte do modelo base)...")

# Descongelar as últimas camadas do modelo base para fine-tuning
# Exemplo: descongelar as últimas 20 camadas (pode variar, ajuste conforme o modelo MobileNetV2)
# Ou descongelar o último bloco (Block_14 e Block_15 da MobileNetV2)
# base_model.trainable = True # Esta linha pode ser usada se quiser descongelar TUDO
# Para descongelar apenas as últimas camadas, você faz um loop:
for layer in base_model.layers:
    if not isinstance(layer, tf.keras.layers.BatchNormalization): # É comum manter BN congelado
        layer.trainable = True # Torna todas as camadas treináveis
# Alternativamente, para descongelar apenas as últimas N camadas:
# for layer in base_model.layers[-20:]: # Descongela as últimas 20 camadas. Ajuste este número!
#     layer.trainable = True
# para manter algumas primeiras camadas congeladas e descongelar as ultimas:
# for layer in base_model.layers[:-N_CAMADAS_A_CONGELAR_DO_FINAL]:
#     layer.trainable = False

# Recompilar o modelo com uma taxa de aprendizado muito menor para fine-tuning
model.compile(
    optimizer=Adam(learning_rate=FINE_TUNE_LEARNING_RATE), # LR menor para fine-tuning
    loss='categorical_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

model.summary() # Verifique se as camadas estão como "trainable=True" agora

history2 = model.fit(
    train_generator,
    # steps_per_epoch=train_generator.samples // BATCH_SIZE, # REMOVA ESTA LINHA
    epochs=TOTAL_EPOCHS,
    initial_epoch=history1.epoch[-1] + 1,
    validation_data=validation_generator,
    # validation_steps=validation_generator.samples // BATCH_SIZE, # REMOVA ESTA LINHA
    callbacks=[early_stopping, model_checkpoint, reduce_lr]
)



# --- Consolidar Históricos para Plotagem ---
# Combine os históricos das duas fases para plotar de forma contínua
history_combined = {}
for key in history1.history.keys():
    history_combined[key] = history1.history[key] + history2.history[key]
# Out:
# Número de classes detectado: 3
# Configurando Data Generators...
# Found 3222 images belonging to 3 classes.
# Found 1057 images belonging to 3 classes.
# Found 624 images belonging to 3 classes.
#
# Construindo o modelo com Transfer Learning...
#
# Compilando o modelo...
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 128, 128, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 64, 64, 32)     │            864 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 64, 64, 32)     │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 64, 64, 32)     │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 64, 64, 32)     │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 64, 64, 32)     │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 64, 64, 32)     │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 64, 64, 16)     │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 64, 64, 16)     │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 64, 64, 96)     │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 64, 64, 96)     │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 64, 64, 96)     │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 65, 65, 96)     │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 32, 32, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 32, 32, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 32, 32, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 32, 32, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 32, 32, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 32, 32, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 32, 32, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 32, 32, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 32, 32, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 32, 32, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 32, 32, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 32, 32, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 32, 32, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 32, 32, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 32, 32, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 32, 32, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 32, 32, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 33, 33, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 16, 16, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 16, 16, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 16, 16, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 16, 16, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 16, 16, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 16, 16, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 16, 16, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 16, 16, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 16, 16, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 16, 16, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 16, 16, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 16, 16, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 16, 16, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 16, 16, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 16, 16, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 16, 16, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 16, 16, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 16, 16, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 16, 16, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 16, 16, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 16, 16, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 16, 16, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 16, 16, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 16, 16, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 16, 16, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 16, 16, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 17, 17, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 8, 8, 192)      │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 8, 8, 192)      │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 8, 8, 192)      │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 8, 8, 64)       │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 8, 8, 64)       │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 8, 8, 384)      │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 8, 8, 384)      │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 8, 8, 384)      │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 8, 8, 384)      │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 8, 8, 384)      │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 8, 8, 384)      │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 8, 8, 64)       │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 8, 8, 64)       │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 8, 8, 64)       │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 8, 8, 384)      │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 8, 8, 384)      │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 8, 8, 384)      │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 8, 8, 384)      │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 8, 8, 384)      │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 8, 8, 384)      │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 8, 8, 64)       │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 8, 8, 64)       │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 8, 8, 64)       │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 8, 8, 384)      │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 8, 8, 384)      │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 8, 8, 384)      │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 8, 8, 384)      │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 8, 8, 384)      │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 8, 8, 384)      │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 8, 8, 64)       │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 8, 8, 64)       │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 8, 8, 64)       │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 8, 8, 384)      │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 8, 8, 384)      │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 8, 8, 384)      │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 8, 8, 384)      │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 8, 8, 384)      │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 8, 8, 384)      │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 8, 8, 96)       │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 8, 8, 96)       │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 8, 8, 576)      │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 8, 8, 576)      │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 8, 8, 576)      │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 8, 8, 576)      │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 8, 8, 576)      │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 8, 8, 576)      │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 8, 8, 96)       │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 8, 8, 96)       │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 8, 8, 96)       │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 8, 8, 576)      │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 8, 8, 576)      │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 8, 8, 576)      │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 8, 8, 576)      │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 8, 8, 576)      │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 8, 8, 576)      │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 8, 8, 96)       │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 8, 8, 96)       │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 8, 8, 96)       │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 8, 8, 576)      │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 8, 8, 576)      │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 8, 8, 576)      │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 9, 9, 576)      │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 4, 4, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 4, 4, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 4, 4, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 4, 4, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 4, 4, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 4, 4, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 4, 4, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 4, 4, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 4, 4, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 4, 4, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 4, 4, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 4, 4, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 4, 4, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 4, 4, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 4, 4, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 4, 4, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 4, 4, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 4, 4, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 4, 4, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 4, 4, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 4, 4, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 4, 4, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 4, 4, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 4, 4, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 4, 4, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 4, 4, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 4, 4, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 4, 4, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 4, 4, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 4, 4, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 4, 4, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 4, 4, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 4, 4, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 4, 4, 1280)     │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 256)            │        327,936 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (None, 256)            │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 3)              │            771 │ dropout_2[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,586,691 (9.87 MB)
#  Trainable params: 328,707 (1.25 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Iniciando o treinamento do modelo...
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5891 - loss: 0.9830 - precision_2: 0.6154 - recall_2: 0.5593
# Epoch 1: val_accuracy improved from -inf to 0.72727, saving model to /content/dados_processados/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 30s 196ms/step - accuracy: 0.5897 - loss: 0.9810 - precision_2: 0.6160 - recall_2: 0.5598 - val_accuracy: 0.7273 - val_loss: 0.6548 - val_precision_2: 0.7554 - val_recall_2: 0.6932
# Epoch 2/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8125 - loss: 0.4615 - precision_2: 0.8387 - recall_2: 0.8125
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: val_accuracy did not improve from 0.72727
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.4615 - precision_2: 0.8387 - recall_2: 0.8125 - val_accuracy: 0.7178 - val_loss: 0.6665 - val_precision_2: 0.7526 - val_recall_2: 0.6856
# Epoch 3/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7186 - loss: 0.6207 - precision_2: 0.7497 - recall_2: 0.6900
# Epoch 3: val_accuracy improved from 0.72727 to 0.72917, saving model to /content/dados_processados/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 131ms/step - accuracy: 0.7187 - loss: 0.6206 - precision_2: 0.7497 - recall_2: 0.6900 - val_accuracy: 0.7292 - val_loss: 0.6466 - val_precision_2: 0.7542 - val_recall_2: 0.6771
# Epoch 4/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6875 - loss: 0.6937 - precision_2: 0.6897 - recall_2: 0.6250
# Epoch 4: val_accuracy improved from 0.72917 to 0.73390, saving model to /content/dados_processados/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6875 - loss: 0.6937 - precision_2: 0.6897 - recall_2: 0.6250 - val_accuracy: 0.7339 - val_loss: 0.6266 - val_precision_2: 0.7629 - val_recall_2: 0.6884
# Epoch 5/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7313 - loss: 0.5768 - precision_2: 0.7531 - recall_2: 0.7044
# Epoch 5: val_accuracy did not improve from 0.73390
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 128ms/step - accuracy: 0.7313 - loss: 0.5769 - precision_2: 0.7530 - recall_2: 0.7043 - val_accuracy: 0.7102 - val_loss: 0.7270 - val_precision_2: 0.7350 - val_recall_2: 0.6723
# Epoch 6/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7812 - loss: 0.6119 - precision_2: 0.8000 - recall_2: 0.7500
# Epoch 6: val_accuracy did not improve from 0.73390
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7812 - loss: 0.6119 - precision_2: 0.8000 - recall_2: 0.7500 - val_accuracy: 0.7017 - val_loss: 0.7554 - val_precision_2: 0.7244 - val_recall_2: 0.6619
# Epoch 7/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7516 - loss: 0.5484 - precision_2: 0.7762 - recall_2: 0.7218
# Epoch 7: val_accuracy improved from 0.73390 to 0.73485, saving model to /content/dados_processados/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 131ms/step - accuracy: 0.7516 - loss: 0.5485 - precision_2: 0.7762 - recall_2: 0.7217 - val_accuracy: 0.7348 - val_loss: 0.6284 - val_precision_2: 0.7556 - val_recall_2: 0.6970
# Epoch 8/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.5938 - loss: 0.6423 - precision_2: 0.6429 - recall_2: 0.5625
# Epoch 8: val_accuracy improved from 0.73485 to 0.73580, saving model to /content/dados_processados/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5938 - loss: 0.6423 - precision_2: 0.6429 - recall_2: 0.5625 - val_accuracy: 0.7358 - val_loss: 0.6385 - val_precision_2: 0.7510 - val_recall_2: 0.6913
# Epoch 9/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7659 - loss: 0.5332 - precision_2: 0.7851 - recall_2: 0.7432
# Epoch 9: val_accuracy did not improve from 0.73580
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.7658 - loss: 0.5335 - precision_2: 0.7849 - recall_2: 0.7431 - val_accuracy: 0.7244 - val_loss: 0.6632 - val_precision_2: 0.7474 - val_recall_2: 0.6837
# Epoch 10/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8125 - loss: 0.5921 - precision_2: 0.8333 - recall_2: 0.7812
# Epoch 10: val_accuracy did not improve from 0.73580
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.5921 - precision_2: 0.8333 - recall_2: 0.7812 - val_accuracy: 0.7358 - val_loss: 0.6281 - val_precision_2: 0.7600 - val_recall_2: 0.6989
# Epoch 11/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7546 - loss: 0.5393 - precision_2: 0.7812 - recall_2: 0.7308
# Epoch 11: val_accuracy improved from 0.73580 to 0.74716, saving model to /content/dados_processados/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 133ms/step - accuracy: 0.7545 - loss: 0.5395 - precision_2: 0.7811 - recall_2: 0.7306 - val_accuracy: 0.7472 - val_loss: 0.6025 - val_precision_2: 0.7653 - val_recall_2: 0.7225
# Epoch 12/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7812 - loss: 0.4982 - precision_2: 0.8276 - recall_2: 0.7500
# Epoch 12: val_accuracy improved from 0.74716 to 0.75473, saving model to /content/dados_processados/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7812 - loss: 0.4982 - precision_2: 0.8276 - recall_2: 0.7500 - val_accuracy: 0.7547 - val_loss: 0.5842 - val_precision_2: 0.7729 - val_recall_2: 0.7282
# Epoch 13/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7599 - loss: 0.5378 - precision_2: 0.7789 - recall_2: 0.7310
# Epoch 13: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.7598 - loss: 0.5379 - precision_2: 0.7788 - recall_2: 0.7309 - val_accuracy: 0.7472 - val_loss: 0.6202 - val_precision_2: 0.7729 - val_recall_2: 0.7121
# Epoch 14/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8125 - loss: 0.4164 - precision_2: 0.8929 - recall_2: 0.7812
# Epoch 14: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8125 - loss: 0.4164 - precision_2: 0.8929 - recall_2: 0.7812 - val_accuracy: 0.7462 - val_loss: 0.6152 - val_precision_2: 0.7704 - val_recall_2: 0.7150
# Epoch 15/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7628 - loss: 0.5298 - precision_2: 0.7843 - recall_2: 0.7414
# Epoch 15: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 129ms/step - accuracy: 0.7628 - loss: 0.5299 - precision_2: 0.7843 - recall_2: 0.7414 - val_accuracy: 0.7453 - val_loss: 0.5771 - val_precision_2: 0.7716 - val_recall_2: 0.7263
# Epoch 16/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.7812 - loss: 0.6412 - precision_2: 0.7812 - recall_2: 0.7812
# Epoch 16: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7812 - loss: 0.6412 - precision_2: 0.7812 - recall_2: 0.7812 - val_accuracy: 0.7443 - val_loss: 0.5818 - val_precision_2: 0.7680 - val_recall_2: 0.7273
# Epoch 17/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7605 - loss: 0.5460 - precision_2: 0.7819 - recall_2: 0.7315
# Epoch 17: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.7606 - loss: 0.5459 - precision_2: 0.7820 - recall_2: 0.7315 - val_accuracy: 0.7509 - val_loss: 0.6151 - val_precision_2: 0.7667 - val_recall_2: 0.7282
# Epoch 18/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8438 - loss: 0.4171 - precision_2: 0.8387 - recall_2: 0.8125
# Epoch 18: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.4171 - precision_2: 0.8387 - recall_2: 0.8125 - val_accuracy: 0.7396 - val_loss: 0.6645 - val_precision_2: 0.7573 - val_recall_2: 0.7150
# Epoch 19/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7707 - loss: 0.5189 - precision_2: 0.7824 - recall_2: 0.7483
# Epoch 19: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 128ms/step - accuracy: 0.7707 - loss: 0.5190 - precision_2: 0.7824 - recall_2: 0.7482 - val_accuracy: 0.7500 - val_loss: 0.6135 - val_precision_2: 0.7629 - val_recall_2: 0.7159
# Epoch 20/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6875 - loss: 0.7851 - precision_2: 0.6875 - recall_2: 0.6875
# Epoch 20: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6875 - loss: 0.7851 - precision_2: 0.6875 - recall_2: 0.6875 - val_accuracy: 0.7500 - val_loss: 0.6017 - val_precision_2: 0.7687 - val_recall_2: 0.7206
# Epoch 21/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7718 - loss: 0.5244 - precision_2: 0.7912 - recall_2: 0.7505
# Epoch 21: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 125ms/step - accuracy: 0.7718 - loss: 0.5244 - precision_2: 0.7912 - recall_2: 0.7505 - val_accuracy: 0.7547 - val_loss: 0.6116 - val_precision_2: 0.7724 - val_recall_2: 0.7358
# Epoch 22/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6875 - loss: 0.4629 - precision_2: 0.7097 - recall_2: 0.6875
# Epoch 22: val_accuracy did not improve from 0.75473
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6875 - loss: 0.4629 - precision_2: 0.7097 - recall_2: 0.6875 - val_accuracy: 0.7528 - val_loss: 0.6323 - val_precision_2: 0.7676 - val_recall_2: 0.7320
# Epoch 23/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7872 - loss: 0.5098 - precision_2: 0.8009 - recall_2: 0.7621
# Epoch 23: val_accuracy improved from 0.75473 to 0.76705, saving model to /content/dados_processados/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 132ms/step - accuracy: 0.7870 - loss: 0.5100 - precision_2: 0.8008 - recall_2: 0.7620 - val_accuracy: 0.7670 - val_loss: 0.5540 - val_precision_2: 0.7915 - val_recall_2: 0.7263
# Epoch 24/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7500 - loss: 0.4830 - precision_2: 0.7419 - recall_2: 0.7188
# Epoch 24: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7500 - loss: 0.4830 - precision_2: 0.7419 - recall_2: 0.7188 - val_accuracy: 0.7661 - val_loss: 0.5549 - val_precision_2: 0.7899 - val_recall_2: 0.7263
# Epoch 25/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7746 - loss: 0.5032 - precision_2: 0.7940 - recall_2: 0.7476
# Epoch 25: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.7746 - loss: 0.5033 - precision_2: 0.7939 - recall_2: 0.7476 - val_accuracy: 0.7453 - val_loss: 0.6094 - val_precision_2: 0.7632 - val_recall_2: 0.7235
# Epoch 26/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8438 - loss: 0.4582 - precision_2: 0.8387 - recall_2: 0.8125
# Epoch 26: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.4582 - precision_2: 0.8387 - recall_2: 0.8125 - val_accuracy: 0.7453 - val_loss: 0.6023 - val_precision_2: 0.7639 - val_recall_2: 0.7263
# Epoch 27/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7682 - loss: 0.5115 - precision_2: 0.7824 - recall_2: 0.7460
# Epoch 27: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.7682 - loss: 0.5115 - precision_2: 0.7825 - recall_2: 0.7459 - val_accuracy: 0.7547 - val_loss: 0.5936 - val_precision_2: 0.7771 - val_recall_2: 0.7330
# Epoch 28/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7188 - loss: 0.6850 - precision_2: 0.7586 - recall_2: 0.6875
# Epoch 28: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7188 - loss: 0.6850 - precision_2: 0.7586 - recall_2: 0.6875 - val_accuracy: 0.7623 - val_loss: 0.5786 - val_precision_2: 0.7829 - val_recall_2: 0.7377
# Epoch 29/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7710 - loss: 0.5286 - precision_2: 0.7849 - recall_2: 0.7428
# Epoch 29: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 128ms/step - accuracy: 0.7711 - loss: 0.5284 - precision_2: 0.7849 - recall_2: 0.7428 - val_accuracy: 0.7405 - val_loss: 0.6453 - val_precision_2: 0.7548 - val_recall_2: 0.7027
# Epoch 30/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8438 - loss: 0.4392 - precision_2: 0.8621 - recall_2: 0.7812
# Epoch 30: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8438 - loss: 0.4392 - precision_2: 0.8621 - recall_2: 0.7812 - val_accuracy: 0.7453 - val_loss: 0.6364 - val_precision_2: 0.7579 - val_recall_2: 0.7083
# Epoch 31/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7799 - loss: 0.4811 - precision_2: 0.7972 - recall_2: 0.7625
# Epoch 31: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.7799 - loss: 0.4812 - precision_2: 0.7972 - recall_2: 0.7625 - val_accuracy: 0.7159 - val_loss: 0.7182 - val_precision_2: 0.7445 - val_recall_2: 0.6790
# Epoch 32/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8750 - loss: 0.3447 - precision_2: 0.8710 - recall_2: 0.8438
# Epoch 32: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8750 - loss: 0.3447 - precision_2: 0.8710 - recall_2: 0.8438 - val_accuracy: 0.7169 - val_loss: 0.7110 - val_precision_2: 0.7420 - val_recall_2: 0.6780
# Epoch 33/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7796 - loss: 0.4955 - precision_2: 0.8000 - recall_2: 0.7564
# Epoch 33: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 127ms/step - accuracy: 0.7796 - loss: 0.4956 - precision_2: 0.8000 - recall_2: 0.7564 - val_accuracy: 0.7396 - val_loss: 0.6519 - val_precision_2: 0.7566 - val_recall_2: 0.7008
# Epoch 34/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7500 - loss: 0.5895 - precision_2: 0.7500 - recall_2: 0.7500
# Epoch 34: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7500 - loss: 0.5895 - precision_2: 0.7500 - recall_2: 0.7500 - val_accuracy: 0.7462 - val_loss: 0.6335 - val_precision_2: 0.7620 - val_recall_2: 0.7064
# Epoch 35/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7639 - loss: 0.5060 - precision_2: 0.7797 - recall_2: 0.7358
# Epoch 35: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.7639 - loss: 0.5060 - precision_2: 0.7797 - recall_2: 0.7358 - val_accuracy: 0.7453 - val_loss: 0.6598 - val_precision_2: 0.7622 - val_recall_2: 0.7225
# Epoch 36/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7188 - loss: 0.5800 - precision_2: 0.7097 - recall_2: 0.6875
# Epoch 36: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7188 - loss: 0.5800 - precision_2: 0.7097 - recall_2: 0.6875 - val_accuracy: 0.7472 - val_loss: 0.6557 - val_precision_2: 0.7642 - val_recall_2: 0.7273
# Epoch 37/50
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7739 - loss: 0.4947 - precision_2: 0.7888 - recall_2: 0.7526
# Epoch 37: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 13s 126ms/step - accuracy: 0.7739 - loss: 0.4947 - precision_2: 0.7889 - recall_2: 0.7525 - val_accuracy: 0.7188 - val_loss: 0.7147 - val_precision_2: 0.7427 - val_recall_2: 0.6941
# Epoch 38/50
#   1/100 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8438 - loss: 0.3485 - precision_2: 0.8333 - recall_2: 0.7812
# Epoch 38: val_accuracy did not improve from 0.76705
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8438 - loss: 0.3485 - precision_2: 0.8333 - recall_2: 0.7812 - val_accuracy: 0.7320 - val_loss: 0.7115 - val_precision_2: 0.7541 - val_recall_2: 0.7027
#
# -------------------------------------------------
# Avaliando o modelo no conjunto de teste...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8370 - loss: 0.5260 - precision_2: 0.8897 - recall_2: 0.7984
#
# Resultados no Conjunto de Teste:
#   Loss: 0.5331
#   Accuracy: 0.8388
#   Precision: 0.8766
#   Recall: 0.7829

# %%
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'precision_2', 'recall_2', 'val_accuracy', 'val_loss', 'val_precision_2', 'val_recall_2'])

# %% [markdown]
# # Gerador de Graficos

# %%
# --- 8. AVALIAR O MODELO NO CONJUNTO DE TESTE ---
print("\n-------------------------------------------------")
print("Avaliando o modelo no conjunto de teste...")
test_results = model.evaluate(test_generator, steps=test_generator.samples // BATCH_SIZE, verbose=1)

print(f"\nResultados no Conjunto de Teste:")
print(f"  Loss: {test_results[0]:.4f}")
print(f"  Accuracy: {test_results[1]:.4f}")
print(f"  Precision: {test_results[2]:.4f}")
print(f"  Recall: {test_results[3]:.4f}")


# --- Opcional: Visualizar o Histórico de Treinamento ---
print("\nGerando gráficos de histórico de treinamento...")

# Use o histórico combinado para os gráficos
num_epochs_trained = len(history_combined['accuracy'])

plt.figure(figsize=(15, 10))

# Plot da Acurácia
plt.subplot(2, 2, 1)
plt.plot(history_combined['accuracy'], label='Acurácia de Treino')
plt.plot(history_combined['val_accuracy'], label='Acurácia de Validação')
plt.scatter(num_epochs_trained - 1, test_results[1], color='red', marker='*', s=200, label='Acurácia de Teste')
plt.title('Acurácia do Modelo ao longo das Épocas')
plt.xlabel('Época')
plt.ylabel('Acurácia')
plt.legend()
plt.grid(True)

# Plot da Perda (Loss)
plt.subplot(2, 2, 2)
plt.plot(history_combined['loss'], label='Perda de Treino')
plt.plot(history_combined['val_loss'], label='Perda de Validação')
plt.scatter(num_epochs_trained - 1, test_results[0], color='red', marker='*', s=200, label='Perda de Teste')
plt.title('Perda do Modelo ao longo das Épocas')
plt.xlabel('Época')
plt.ylabel('Perda')
plt.legend()
plt.grid(True)

# Plot da Precisão
plt.subplot(2, 2, 3)
plt.plot(history_combined['precision'], label='Precisão de Treino')
plt.plot(history_combined['val_precision'], label='Precisão de Validação')
plt.scatter(num_epochs_trained - 1, test_results[2], color='red', marker='*', s=200, label='Precisão de Teste')
plt.title('Precisão do Modelo ao longo das Épocas')
plt.xlabel('Época')
plt.ylabel('Precisão')
plt.legend()
plt.grid(True)

# Plot do Recall
plt.subplot(2, 2, 4)
plt.plot(history_combined['recall'], label='Recall de Treino')
plt.plot(history_combined['val_recall'], label='Recall de Validação')
plt.scatter(num_epochs_trained - 1, test_results[3], color='red', marker='*', s=200, label='Recall de Teste')
plt.title('Recall do Modelo ao longo das Épocas')
plt.xlabel('Época')
plt.ylabel('Recall')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print("\n--- Treinamento e Avaliação Concluídos ---")
# Out:
# Gerando gráficos de histórico de treinamento...
# --- Treinamento e Avaliação Concluídos ---
